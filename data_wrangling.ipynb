# %%
# Dependencies
import pandas as pd

# %%
# Create Pandas DataFrame with data
heart_df = pd.read_csv("Resources/Heart_Disease_Prediction.csv")
heart_df.head()
# Out:
#    Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0   70    1                4  130          322             0            2
# 1   67    0                3  115          564             0            2
# 2   57    1                2  124          261             0            0
# 3   64    1                4  128          263             0            0
# 4   74    0                2  120          269             0            2
#
#    Max HR  Exercise angina  ST depression  Slope of ST  \
# 0     109                0            2.4            2
# 1     160                0            1.6            2
# 2     141                0            0.3            1
# 3     105                1            0.2            2
# 4     121                1            0.2            1
#
#    Number of vessels fluro  Thallium Heart Disease
# 0                        3         3      Presence
# 1                        0         7       Absence
# ...

# %%
# Convert sex from numerical to categorical: 1 = male; 0 = female
sex = {1: 'Male', 0: 'Female'}
heart_df['Sex'] = heart_df['Sex'].map(sex)

# Convert chest pain type from numerical to categorical
# Value 1: typical angina, Value 2: atypical angina, Value 3: non-anginal pain, Value 4: asymptomatic
chest_pain = {1: 'Typical Angina', 2: 'Atypical Angina', 3: 'Non-Anginal Pain', 4: 'Asymptomatic'}
heart_df['Chest pain type'] = heart_df['Chest pain type'].map(chest_pain)

# Convert FBS over 120 from numerical to categorical
# 1 = true; 0 = false
fbs = {1: True, 0: False}
heart_df['FBS over 120'] = heart_df['FBS over 120'].map(fbs)

# Convert EKG results from numerical to categorical
# Value 0: normal
# Value 1: having ST-T wave abnormality (T wave inversions and/or ST elevation or depression of > 0.05 mV)
# Value 2: showing probable or definite left ventricular hypertrophy by Estes' criteria  
ekg = {0: 'Normal', 1: 'ST-T Abnormality', 2: 'LVH Indication'}
heart_df['EKG results'] = heart_df['EKG results'].map(ekg)
# Out:
#    Age     Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0   70    Male                4  130          322             0            2
# 1   67  Female                3  115          564             0            2
# 2   57    Male                2  124          261             0            0
# 3   64    Male                4  128          263             0            0
# 4   74  Female                2  120          269             0            2
#
#    Max HR  Exercise angina  ST depression  Slope of ST  \
# 0     109                0            2.4            2
# 1     160                0            1.6            2
# 2     141                0            0.3            1
# 3     105                1            0.2            2
# 4     121                1            0.2            1
#
#    Number of vessels fluro  Thallium Heart Disease
# 0                        3         3      Presence
# 1                        0         7       Absence
# ...
